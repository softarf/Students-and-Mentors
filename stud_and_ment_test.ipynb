# %%
# -*- coding: utf-8 -*-

from random import random, sample

def rate_hw_method(evaluator, getting, course, flg, k):  # Выставление оценки.
    #   Если flg == 1, то функция вызвана проверяющим, если flg == 0, то студентом.
    #   k - "коэффициент корректировки успеваемости"
    if type(getting) in (Student, Lecturer):
        if flg == 1:
            ev, gt = evaluator, getting
        elif flg == 0:
            ev, gt = getting, evaluator
        print(gt.name, gt.courses_in_progress, ev.name, ev.courses_attached, course)
        print(' if(all):', course in gt.courses_in_progress, course in ev.courses_attached, end=' ')
        if course in gt.courses_in_progress and course in ev.courses_attached:
            grade = int((random() ** k) * 11)
            getting.grades[course] = getting.grades.get(course, []) + [grade]
            res = grade
        else:
            res = 'Не выставлена'
    else:
        print(' Человек не подходит. Неизвестный класс:', type(getting))
        res = 'Человек не подходит'
    print(res)
    return res

def average_score(grades_dict):  # Подсчёт средней оценки.
    num = 0
    full = 0
    for val in grades_dict.values():
        for score in val:
            num += 1
            full += score
    if num > 0:
        res = full / num
    else:
        res = 0
    return res

def texted(courses_name):  # Печать элементов списка.
    text = ''
    i = 1
    for item in courses_name:
        if i != 1:
            text += ', ' + item
        else:
            text += ' ' + item
        i += 1
    return text

class Men:
    def __init__(self, any_name='Adam', any_surname='', any_sex='м'):
        self.name = any_name             # Имя
        self.surname = any_surname       # Фамилия
        self.sex = any_sex               # Пол

    def __str__(self):
        quote = f' Имя: {self.name}\n Фамилия: {self.surname}'
        return quote

    def _rate_hw_method(evaluator, getting, course, flg, k):  # Выставление оценки.
        #   Если flg == 1, то функция вызвана проверяющим, если flg == 0, то студентом.
        #   k - "коэффициент корректировки успеваемости"
        if type(getting) in (Student, Lecturer):
            if flg == 1:
                ev, gt = evaluator, getting
            elif flg == 0:
                ev, gt = getting, evaluator
            if course in gt.courses_in_progress and course in ev.courses_attached:
                grade = int((random() ** k) * 11)
                getting.grades[course] = getting.grades.get(course, []) + [grade]
                res = grade
            else:
                res = 'Не выставлена'
        else:
            print(' Человек не подходит. Неизвестный класс:', type(getting))
            res = 'Человек не подходит'
        return res

class Student(Men):
    def __init__(self, any_name='Adam', any_surname='', any_sex='м'):
        super().__init__(any_name, any_surname, any_sex)
        self.finished_courses = []       # Завершённые курсы
        self.courses_in_progress = []    # Изучаемые курсы
        self.grades = {}                 # Журнал успеваемости
    
    def add_courses(self, course_name):
        self.finished_courses.append(course_name)
    
    def rate_hw(self, lectur, cours):  # Выставление оценки.
        res = super()._rate_hw_method(lectur, cours, 0, 0.25)
        #res = rate_hw_method(self, lectur, cours, 0, 0.25)
#         if isinstance(lectur, Lecturer) and course in self.courses_in_progress and course in lecturer.courses_attached:
#             # Лектор Adam за Предмет получает Оценку.
#             grade = int((random() ** 0.25) * 11)
#             lectur.grades[course] = lectur.grades.get(course, []) + [grade]
#             res = grade
#         else:
#             res = 'Не выставлена'  # Лектор Adam не ведёт Предмет.
        return res

    def __str__(self):
        quote = super().__str__()
        res = average_score(self.grades)
        quote += f'\n Средняя оценка за домашние задания: {res:4.2f}\n Курсы в процессе изучения:'
        quote += texted(self.courses_in_progress)
        quote += f'\n Завершённые курсы:'
        quote += texted(self.finished_courses)
        return quote
        
    def __lt__(self, other):
        #if type(other) in (Student, ):
        if isinstance(other, Student):
            aver1 = average_score(self.grades)
            aver2 = average_score(other.grades)
            res = aver1 < aver2
        else:
            print(' Человек не подходит. Неизвестный класс:', type(other))
            res = 'Человек не подходит'
        return res

class Teacher(Men):
    def __init__(self, any_name='Adam', any_surname='', any_sex='м'):
        super().__init__(any_name, any_surname, any_sex)
        self.courses_attached = []       # Прикреплённые курсы

#     def __str__(self):
#         # quote = f' Имя: {self.name}\n Фамилия: {self.surname}'
#         quote = super().__str__()
#         return quote

class Lecturer(Teacher):
    def __init__(self, any_name='Adam', any_surname='', any_sex='м'):
        super().__init__(any_name, any_surname, any_sex)
        self.grades = {}                 # Оценки

    def __str__(self):
        quote = super().__str__()
        res = average_score(self.grades)
        quote += f'\n Средняя оценка за лекции: {res:4.2f}'
        return quote
        
    def __lt__(self, other):
        if type(other) in (Lecturer, ):
            aver1 = average_score(self.grades)
            aver2 = average_score(other.grades)
            res = aver1 < aver2
        else:
            print(' Человек не подходит. Неизвестный класс:', type(other))
            res = 'Человек не подходит'
        return res

class Reviewer(Teacher):
    def __init__(self, any_name='Adam', any_surname='', any_sex='м'):
        super().__init__(any_name, any_surname, any_sex)
    
    def rate_hw(self, student, course):  # Выставление оценки.
        #res = super()._rate_hw_method(student, course, 1, 0.5)
        res = rate_hw_method(self, student, course, Student)
#         if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
#             # Студент Adam за Предмет получает Оценку.
#             grade = int((random() ** 0.5) * 11)
#             student.grades[course] = student.grades.get(course, []) + [grade]
#             res = grade
#         else:
#             res = 'Не выставлена'   # Студент Adam не изучает Предмет.
        return res

    def __str__(self):
        quote = super().__str__()
        return quote

def subject_set(received_list, subjects, mn_or_st=1):
    #               Распределение изучаемых предметов среди преподавателей и среди студентов (случаным образом).
    # mn_or_st = 1               # Флаг. Для лекторов = 1, для проверяющих = -1, для студентов = 0.
    if mn_or_st != 0:            # Кол-во предметов: для менторов = 1 - 3, для студентов = 4 - 6.
        sbj_n = 1
    else:
        sbj_n = 4
    ment_q = len(received_list)  # (menters_quantity) Преподавателей всего (остальные проверяющие), или студентов.
    all_set = set()
    for i in range(len(subjects)):
        all_set.add(i)
    my_set = set()
    for i in range(ment_q - abs(mn_or_st)):
        quant = int(random() * (3)) + sbj_n  # Один преподаватель может вести от одного до трёх предметов.
        #                  (У последнего может быть другое). Один студент может изучать от 4-ти до 6-ми предметов.
        my_list = list(sample(range(6), quant))  # Индексы выбранных предметов.
        for j in range(len(my_list)):
            subject = subjects[my_list[j]]
            if mn_or_st != 0:
                received_list[i].courses_attached.append(subject)
                my_set.add(my_list[j])
            else:
                if j < 2:  # Первые два предмета у студентов запишем как пройденные (finished_courses).
                    # Воспользуемся методом .add_courses() встроенным в класс Student.
                    received_list[i].add_courses(subject)
                    # Или можно обоатиться к атрибуту .finished_courses напрямую.
                    # received_list[i].finished_courses.append(subject)
                else:      # Остальные как изучаемые.
                    received_list[i].courses_in_progress.append(subject)
                    received_list[i].grades[subject] = []
            if mn_or_st == 1:
                received_list[i].grades[subject] = []
        # if mn_or_st != -1:      # Для теста
            # print(' this_dict:', received_list[i].grades)
    not_includ = all_set - my_set
    if mn_or_st != 0:
        if len(not_includ) > 0:
            for now in not_includ:
                subject = subjects[now]
                received_list[ment_q - 1].courses_attached.append(subject)
                if mn_or_st != -1:
                    received_list[ment_q - 1].grades[subject] = []
        else:
            received_list[ment_q - 1].courses_attached.append(subjects[2])
            if mn_or_st != -1:
                received_list[ment_q - 1].grades[subjects[2]] = []
        # if mn_or_st != -1:      # Для теста
            # print(' this_dict:', received_list[ment_q - 1].grades)
    # print(' not includ:', not_includ, '  my_set:', my_set, '  all_set:', all_set)

'''        Упрощённый вариант, использовал в ДЗ.'''
# def subject_set(received_list, subjects, mn_or_st=1):
#     k = 0
#     for i in range(len(received_list)):
#         for j in range(len(subjects) - abs(mn_or_st)):
#             if mn_or_st != 0:
#                 received_list[i].courses_attached.append(subjects[k % 3])
#                 k += 1
#             else:
#                 if j == i % 3:  # Данный предмет для студента запишем в пройденные (finished_courses).
#                     # Воспользуемся методом .add_courses() встроенным в класс Student.
#                     received_list[i].add_courses(subjects[j])
#                     # Или можно обратиться к атрибуту .finished_courses напрямую.
#                     # received_list[i % 5].finished_courses.append(subjects[j])
#                 else:      # Остальные как изучаемые.
#                     received_list[i].courses_in_progress.append(subjects[j])

def data_input(file_name):
    students_list = []
    mentors_list = []
    lecturers_list = []
    reviewers_list = []
    subjects_list = []
    with open(file_name, 'r', encoding='utf8') as in_file:
        for i in range(15):
            word_line = in_file.readline().strip().split()
            one_student = Student(word_line[1], word_line[0], word_line[2])
            students_list.append(one_student)
        for i in range(12):
            word_line = in_file.readline().strip().split()
            mentors_list.append(word_line)
        for i in range(6):
            word_line = in_file.readline().strip()
            subjects_list.append(word_line)
    #    Назначим лекторов (выберем шестерых, случайным образом), остальные станут проверяющими.
    my_list = list(sample(range(12), 6))
    for i in range(12):
        if i in my_list:
            one_lecturer = Lecturer(mentors_list[i][0], mentors_list[i][1], mentors_list[i][2])
            lecturers_list.append(one_lecturer)
        else:
            one_reviewer = Reviewer(mentors_list[i][0], mentors_list[i][1], mentors_list[i][2])
            reviewers_list.append(one_reviewer)
    subject_set(lecturers_list, subjects_list, 1)
    subject_set(reviewers_list, subjects_list, -1)
    subject_set(students_list, subjects_list, 0)
    
    return lecturers_list, reviewers_list, students_list, subjects_list

def course_average(analyzeds, course):
    num = 0
    full = 0
    for men in analyzeds:
        if course in men.grades.keys():
            val = men.grades[course]
            for score in val:
                num += 1
                full += score
    if num > 0:
        res = full / num
    else:
        res = 0
    return res

def print_list(men, flag):
    print(f' Имя: {men.name}   Фамилия: {men.surname}   Пол: {men.sex}')
    print(' Предметы:', end='')
    if flag != 0:
        print(men.courses_attached)
    else:
        print(men.finished_courses)
        print(men.courses_in_progress)
    if flag != -1: print(' Оценки: ', men.grades)


#                                         Головной блок
#                  1. Наследование классов.
#                     Использовал чтение из файла, чтобы упростить тестирование.
lecturers, reviewers, students, courses = data_input('input.txt')

#                  2.1 "Каждый проверяющий выставляет по три оценки каждому студенту". Вариант из ДЗ.
# for i in range(len(reviewers)):
#     rev = reviewers[i]
#     for j in range(len(students)):
#         stud = students[j]
#         for k in range(len(courses)):
#             cour = courses[k]
#             for m in range(3):
#                 result = rev.rate_hw(stud, cour)
#                  2.1 Проверяющие выставляют оценки за домашние задания студентам
rev_list = list(sample(range(6), 2))  # Выберем 2 проверяющих.
for i in range(2):
    rev = reviewers[rev_list[i]]
    stud_list = list(sample(range(15), 2))  # Выберем 2 студентов.
    for j in range(2):
        stud = students[stud_list[j]]
        cour_list = list(sample(range(6), 4))  # Выберем 4 курса из полого списка преподаваемых предметов.
        for k in range(4):
            cour = courses[cour_list[k]]
            result = rev.rate_hw(stud, cour)
#             quote = f'Проверил: {rev.surname} {rev.name}, студент: {stud.name}'  # Для теста.
#             print(f' {quote} {stud.surname}, курс: {cour}, оценка: {result}')     # Для теста.

#                  2.1.a Тестирование на иной класс. Для теста.
# Tom = Men('Василий', 'Петров', 'м')
# rev = reviewers[2]
# stud = Tom
# cour = 'Git'
# result = rev.rate_hw(stud, cour)
# quote = f'Проверил: {rev.surname} {rev.name}, оцениваемый: {stud.name} {stud.surname},'  # Для теста.
# print(f' {quote} соотв. типа: {type(stud) in (Student, Lecturer)}, курс: {cour}, оценка: {result}')     # Для теста.
# Jerry = Teacher('Алёна', 'Батицкая', 'ж')
# rev = reviewers[2]
# stud = Jerry
# cour = 'Git'
# result = rev.rate_hw(stud, cour)
# quote = f'Проверил: {rev.surname} {rev.name}, оцениваемый: {stud.name} {stud.surname},'  # Для теста.
# print(f' {quote} соотв. типа: {type(stud) in (Student, Lecturer)}, курс: {cour}, оценка: {result}')     # Для теста.

#                  2.2 "Каждый студент выставляет по одной оценке каждому лектору". Вариант из ДЗ.
# for i in range(len(students)):
#     stud = students[i]
#     for j in range(len(lecturers)):
#         lec = lecturers[j]
#         for k in range(len(courses)):
#             cour = courses[k]
#             result = stud.rate_hw(lec, cour)
#                  2.2 Студенты выставляют оценки лекторам
stud_list = list(sample(range(15), 2))  # Выберем 2 студентов.
for i in range(2):
    stud = students[stud_list[i]]
    lec_list = list(sample(range(6), 2))  # Выберем 2 лекторов.
    for j in range(2):
        lec = lecturers[lec_list[j]]
        cour_list = list(sample(range(6), 5))  # Выберем 5 курсов.
        for k in range(5):
            cour = courses[cour_list[k]]
            result = stud.rate_hw(lec, cour)
#             quote = f'Студент: {stud.name} {stud.surname}, лектор: {lec.surname}'  # Для теста.
#             print(f' {quote} {lec.name}, курс: {cour}, оценка: {result}')           # Для теста.

#                  3.1 Перегрузка магического метода __str__
print('\n В этом учебном году.')
print('\n Лекторы:')
for pers in lecturers:
    print(pers)
print('\n Проверяющие:')
for pers in reviewers:
    print(pers)
print('\n Студенты:')
for pers in students:
    print(pers)

#                  3.2 Сравнивание между собой по средней оценке.
print()
print(lecturers[1] < lecturers[0])
print(students[2] < students[1])
print(students[0] < lecturers[2])

#                  4.1 Подсчёт средней оценки за домашние задания по всем студентам в рамках конкретного курса.
course = 'Основы программирования на Python'
stud_aver = course_average(students, course)
print(f'\n course: {course},  stud_aver = {stud_aver:4.2f}')

#                  4.2 Подсчёт средней оценки за лекции всех лекторов в рамках конкретного курса.
course = 'SQL и получение данных'
lec_aver = course_average(lecturers, course)
print(f' course: {course},  lec_aver = {lec_aver:4.2f}')


#                  Печать конечного состояния. Для теста.
my_list = [lecturers, reviewers, students]
flags = [('Лекторы.', 1), ('Проверяющие.', -1), ('Студенты.', 0)]
for i in range(3):
    print()
    print(flags[i][0])
    flg = flags[i][1]
    for now in my_list[i]:
        print_list(now, flg)

print('\n  -- Конец --  ')  #                 - Для блокнота
#input('\n  -- Конец --  ')	#	Типа  "Пауза" - Для среды
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-379f66abe4e0> in <module>
#     320         for k in range(4):
#     321             cour = courses[cour_list[k]]
# --> 322             result = rev.rate_hw(stud, cour)
#     323 #             quote = f'Проверил: {rev.surname} {rev.name}, студент: {stud.name}'  # Для теста.
#     324 #             print(f' {quote} {stud.surname}, курс: {cour}, оценка: {result}')     # Для теста.
#
# <ipython-input-1-379f66abe4e0> in rate_hw(self, student, course)
#     157     def rate_hw(self, student, course):  # Выставление оценки.
#     158         #res = super()._rate_hw_method(student, course, 1, 0.5)
# --> 159         res = rate_hw_method(self, student, course, Student)
#     160 #         if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress:
#     161 #             # Студент Adam за Предмет получает Оценку.
#
# TypeError: rate_hw_method() missing 1 required positional argument: 'k'
